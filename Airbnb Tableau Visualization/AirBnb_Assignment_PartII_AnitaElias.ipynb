# %% [markdown]
# # AirBnB Assignment Part II Stub File
# ---

# %% [markdown]
# #### Guidelines
#
# - Go through the data dictionary thoroughly before starting the assignment. That will give you a good idea of what each column represents before you begin the analysis.
#
#
# - Read each instruction carefully, identify the task to be performed, and only then write the required code. The assignment is meant to be straightforward. You do not need to perform additional analyses that are not requested explicitly. However you are encouraged to perform a few additional analyses to get deeper into the insights
#
#
# - Some of the tasks might require using functions you may not have used previously. In such cases, you should rely on the library documentation you referred to in the modules. Please understand that completing this assignment is a learning process, and research is part of it.
#
#
# - Always run the cells of the Notebook sequentially, restart the kernel, and run all the cells to avoid runtime errors.
#
#
# - For each of the tasks, there's a code cell where you are supposed to write the code and a markdown cell below it mentioning to either write the answer or mention your observations/insights from the output of the code.
#
#
# - Many of the questions will require you to view them from multiple angles. You have been asked to **observe any trends in the visualizations and provide insights for these trends**. In other words, there will be no fixed answers. You are expected to apply your problem-solving skills to come up with solutions and also document your work appropriately; both of these are part of the assignment grading.

# %%
##Import the libraries
import pandas as pd
import numpy as np
import seaborn as sns

import warnings 
warnings.filterwarnings("ignore")

# %%
#Load the Airbnb dataset
air_df = pd.read_csv("airbnblistings.csv")
air_df.shape
# Out:
# (6173, 22)

# %%
# Column name
air_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'host_since_Year',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'accommodates', 'bedrooms'],
#       dtype='object')

# %%
#check the top 5 rows
air_df.head()
# Out:
#       id                                               name  host_id  \
# 0   2818           Quiet Garden View Room & Super Fast WiFi     3159
# 1  20168       Studio with private bathroom in the centre 1    59484
# 2  27886  Romantic, stylish B&B houseboat in canal district    97647
# 3  28871                            Comfortable double room   124245
# 4  29051                            Comfortable single room   124245
#
#    host_name  host_since_Year                           neighbourhood  \
# 0     Daniel             2008  Oostelijk Havengebied - Indische Buurt
# 1  Alexander             2009                            Centrum-Oost
# 2       Flip             2010                            Centrum-West
# 3      Edwin             2010                            Centrum-West
# 4      Edwin             2010                            Centrum-Oost
#
#    latitude  longitude     room_type  price  ...  last_review  \
# 0  52.36435    4.94358  Private room     49  ...   2022-06-01
# ...

# %% [markdown]
# # Task 1
# ---
# Basic Descriptive Statistics
# ### - 1.1 How many AirBnB listings are there in the city of Amsterdam?

# %% [markdown]
# **Answer**:

# %%
# Taking the entire shape of data set to get the count of listings.
print("The number of AirBnB listings in the city of Amsterdam is:", air_df.shape[0])
# Out:
# The number of AirBnB listings in the city of Amsterdam is: 6173

# %% [markdown]
# ### - 1.2 What is the average price of all the AirBnB listings in Amsterdam?

# %% [markdown]
# **Answer**:

# %%
# Finding the mean value of the 'price' field 
print(f"The average price of all the AirBnB listings in Amsterdam is: {air_df['price'].mean():.2f}")
# Out:
# The average price of all the AirBnB listings in Amsterdam is: 198.02

# %% [markdown]
# ### - 1.3 - What is the average rating received by all the AirBnB listings in Amsterdam? *Hint* - Use the `review_scores_rating` column for answering this question

# %% [markdown]
# **Answer**:

# %%
# Finding the mean value of the 'review_scores_rating' field 
print(f"The average rating of all the AirBnB listings in Amsterdam is: {air_df['review_scores_rating'].mean():.2f}")
# Out:
# The average rating of all the AirBnB listings in Amsterdam is: 4.80

# %% [markdown]
# # Task 2
# ---
#
# ### Plot a histogram for the following variables and observe their distribution. Choose the parameters like bin width, number of bins, etc. as per your choice.
#
# - `price`
# - `number_of_reviews`
# - `review_scores_rating`

# %% [markdown]
# ### Task 2 -> Part I - 'Price'
# ---

# %%
#Write your code here for plotting the distribution of price
import matplotlib.pyplot as plt
bin_start = 0
bin_end = 2000
bin_width = 50
air = sns.histplot(air_df['price'], alpha=0.7, color='blue',bins=range(bin_start, bin_end, bin_width))
plt.axvline(air_df.price.mean(), color ='red')
plt.axvline(air_df.price.median(), color ='yellow')
plt.title('Distribution of Booking Prices')
plt.xlabel('Price in Euros')
plt.ylabel('Frequency')
plt.show()
#Also printing skew value:
print(air_df.price.skew())
# Out:
# 4.119345707351837

# %% [markdown]
# **Observation**:

# %% [markdown]
# ### Here are the inferences based on observations:
# 1) There is a steep drop-off in frequency as prices rise, highlighting the concentration of listings in the more affordable range.
# 2) As the price for rooms increase, the number of bookings made comes down. The least bookings are for rooms that cost above 500 Euros. This pattern suggests that luxury accommodations are much less common.
# 3) The maximum number of bookings are being made for the rooms in the more affordable range of 50 - 150 Euros.
# 4) The distribution is a right skewed distribution.

# %% [markdown]
# ### Task 2 -> Part II - 'Distribution of Reviews'
# ---

# %%
##Write your code here for plotting the distribution of reviews
import matplotlib.pyplot as plt
bin_start = 0
bin_end = 2000
bin_width = 50
air = sns.histplot(air_df['number_of_reviews'], alpha=0.7, color='blue',bins=range(bin_start, bin_end, bin_width))
plt.title('Distribution of Reviews is lower for majority of Listings')
plt.xlabel('Distribution of Reviews')
plt.ylabel('Frequency')
plt.axvline(air_df.number_of_reviews.mean(), color ='red')
plt.axvline(air_df.number_of_reviews.median(), color ='yellow')
plt.show()
#Also printing skew value:
print(air_df.number_of_reviews.skew())
# Out:
# 3.9678855496779804

# %% [markdown]
# **Observation**:

# %% [markdown]
# ### Here are the inferences based on observations:
# 1) A large majority of listings have a relatively low number of reviews.
# 2) The first bin appears to contain the highest frequency with around 4500 listings, which is approximately 70% of all listings combined - 6173.
# 3) The frequency decreases significantly as the number of reviews increases. This suggests that newer or less popular listings dominate the platform, or that guests tend to leave reviews infrequently.
# 4) The distribution is a right skewed distribution.

# %% [markdown]
# ### Task 2 -> Part III - 'Review of Score Ratings'
# ---

# %%
##Write your code here for plotting the distribution of ratings
import matplotlib.pyplot as plt

air = sns.histplot(air_df['review_scores_rating'], alpha=0.7, color='blue',bins=10)
plt.title('Histogram for Distribution of Review of Score Ratings')
plt.xlabel('Distribution of Review of Score Ratings')
plt.ylabel('Frequency')
plt.axvline(air_df.review_scores_rating.mean(), color ='red')
plt.axvline(air_df.review_scores_rating.median(), color ='yellow')
plt.show()
#Also printing skew value:
print(air_df.review_scores_rating.skew())
# Out:
# -7.214232166676065

# %% [markdown]
# **Observation**:

# %% [markdown]
# ### Here are the inferences based on observations:
# 1) The histogram for 'review_scores_rating' shows a left-skewed distribution, indicating that most properties have high ratings.
# 2) The majority of the properties received a rating in the highest bin range of **4.5 to 5.0 star rating**. This could be indicative of a positive customer experience, positive brand perception or a bias towards leaving positive reviews.
# 3) There is a significant drop in frequency as the rating decreases, with the next most populated bin being **4.0 to 4.5 stars** containing only roughly around 400 or so properties.

# %% [markdown]
# # Task 3
# ---
#
# Plot a visualization to show the number of listings for each `room_type`
#
# Which `room_type` has the highest number of listings?

# %%
sns.set_style("whitegrid")
g = sns.countplot(data=air_df, x="room_type", color="blue")
g.set(xlabel = "Room Type", ylabel= "Count of ID")
plt.show()

# %%
# Sorting the above plot:
sns.set_style("whitegrid")
g = sns.countplot(data=air_df, x="room_type", color="blue", order=air_df["room_type"].value_counts().index)
g.set(xlabel = "Room Type", ylabel= "Count of ID")
plt.show()

# %% [markdown]
# **Observation** -

# %%
print("The room type that has the highest number of listings of about 4200 is Entire Home/Apartments")
# Out:
# The room type that has the highest number of listings of about 4200 is Entire Home/Apartments

# %% [markdown]
# # Task 4
# ---
#
# You want to observe the relationship between the reviews(given by `number_of_reviews`) and the ratings received (`review_scores_rating`) by different AirBnB listings.
#
# For this, plot both a scatterplot and a jointplot. What can you say about the relationship between ratings and reviews?

# %%
##Write your code here for scatterplot
sns.scatterplot(data=air_df,
                x="number_of_reviews",
                y="review_scores_rating",
                hue="room_type")
plt.title('Scatterplot depicting relationship between Reviews and Review Score Ratings')
plt.xlabel('Number of Reviews')
plt.ylabel('Review Score Ratings')
plt.show()

# %%
##Write your code here for jointplot
sns.jointplot(data=air_df, x="number_of_reviews", y="review_scores_rating", hue="room_type")
plt.xlabel('Number of Reviews')
plt.ylabel('Review Score Ratings')
plt.show()

# %% [markdown]
# **Observation** -

# %% [markdown]
# 1) From the scatterplot, it appears that there is a positive relationship between the number of reviews and the review scores ratings. This means that as the number of reviews increases, the review scores ratings also tend to increase.
#
# 2) In the jointplot, we see that the distribution of review scores ratings becomes more concentrated at higher values as the number of reviews increases.
#
# 3) Overall, we can say that there is a positive correlation between the number of reviews and the review scores ratings, indicating that listings with more reviews tend to have higher ratings.

# %% [markdown]
# # Task 5
# ---
#
# AirBnB has been adding quite a few listings in the city of Amseterdam since they started operating in 2008. Plot a lineplot to observe how the average `review_scores_rating` has changed across the different years (use `host_since_Year` column) AirBnB has been operating in the city.

# %%
### Write your code for lineplot here
sns.lineplot(data=air_df, x="host_since_Year", y="review_scores_rating")
plt.title('Average Review Score Rating Trends Over The Years')
plt.xlabel('Host Since Year')
plt.ylabel('Review Score Ratings')
plt.show()

# %% [markdown]
# **Observation** -

# %% [markdown]
# 1) A dip has been observed in the average review scores ratings between 2008 and 2010, followed by an increase in ratings from 2010 onwards. This initial dip could be attributed to the early stages of AirBnB's operation in Amsterdam, during which the platform was still gaining popularity and establishing itself in the city.
# 2) After 2010, we see a generally upward trend in the average review scores ratings, indicating a positive reception and possibly an improvement in the quality of listings and services offered.
# 3) However, after 2016, there is a downward trend in the average review scores ratings. This could be due to a variety of factors, such as an increase in the number of listings leading to more competition, changes in the types of listings being offered, or shifts in customer preferences or external environmental factors like onset of Covid.
# 4) In conclusion, we can see both positive and negative shifts in the perception of AirBnB as a brand with its listings in Amsterdam.

# %% [markdown]
# # Task 6
# ---
#
# You wish to identify the relationship between the various ratings each of the listing has received from the customers.
# These ratings have been summarized below:

# %%
review_columns = ['review_scores_rating',
 'review_scores_accuracy',
 'review_scores_cleanliness',
 'review_scores_checkin',
 'review_scores_communication',
 'review_scores_location',
 'review_scores_value']
print(review_columns)
# Out:
# ['review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value']

# %% [markdown]
# ### Plot a heatmap of the correlation matrix of the above ratings variables and document your observations. You can use this link to understand these variables further - https://www.airbnb.co.in/help/article/1257/star-ratings

# %%
sns.heatmap(air_df[review_columns].corr(), cmap="Greens", annot=True)
plt.show()

# %% [markdown]
# **Observation** -

# %% [markdown]
# 1) Based on the heatmap, it appears that there is a generally high positive correlation between the different review scores. This means that listings with high ratings in one category tend to have high ratings in others.
#
# 2) This insight is valuable as it indicates that customer ratings across different aspects of the listing (accuracy, cleanliness, check-in experience, communication, location, and value) are positively related. This suggests that customers who are satisfied with one aspect of their stay are likely to be satisfied with other aspects as well.
#
# 3) This information can be used by AirBnB hosts and management to understand the interconnectedness of customer satisfaction across different dimensions and to focus on improving overall quality and customer experience.

# %% [markdown]
# # Task 7
# ---

# %% [markdown]
# ### Analyze the listings' prices across the following neighborhoods using a categorical boxplot
# - 'Westerpark', 'Oud-Noord', 'Noord-West','Zuid'

# %%
nc = ['Westerpark', 'Oud-Noord', 'Noord-West','Zuid']

# %%
### Creating a variable ncb - for creating subset of neighborhoods. 
ncb = ['Westerpark', 'Oud-Noord', 'Noord-West','Zuid']
ncb
# Out:
# ['Westerpark', 'Oud-Noord', 'Noord-West', 'Zuid']

# %%
### Write your code for subsetting the data for only the above neighborhoods here. 
air_df2 = air_df.loc[air_df['neighbourhood'].isin(ncb)]
air_df2.head()
# Out:
#         id                                        name  host_id host_name  \
# 9    55868         Apartment near Museumplein (centre)   264178  Cornelie
# 15   97476  Spacious, bright apartment near Vondelpark   485930    Rachel
# 33  262394           Charming Studio with Roof Terrace  1376607    Martin
# 35  283170          5-bedrooms house; central location  1451657     Marco
# 59  414865            Charming house, perfect for two!  2063261   Miranda
#
#     host_since_Year neighbourhood  latitude  longitude        room_type  \
# 9              2010          Zuid  52.35597    4.88512  Entire home/apt
# 15             2011          Zuid  52.35665    4.86363  Entire home/apt
# 33             2011          Zuid  52.35695    4.85234     Private room
# 35             2011          Zuid  52.35435    4.87316  Entire home/apt
# 59             2012          Zuid  52.35043    4.84676  Entire home/apt
#
#     price  ...  last_review  review_scores_rating review_scores_accuracy  \
# ...

# %%
### Write your code for plotting the categorical boxplot here
sns.boxplot(x="neighbourhood", y="price", data=air_df2)
plt.title('Price Listings for the Westerpark, Oud-Noord, Noord-West and Zuid Neighborhoods')
plt.xlabel('Neighborhood')
plt.ylabel('Price Listing')
plt.show()

# %% [markdown]
# **Observation** -

# %% [markdown]
# 1) We can observe that there are specific outliers for the Zuid and Oud-Noord neighborhoods in the boxplot indicating that there are listings in these neighborhoods with prices significantly higher than the typical range of prices for the majority of listings in those areas. For Zuid and Oud-Noord, the higher-priced outliers suggest that there maybe some luxury or high-end listings in these neighborhoods.
# 2) In contrast, the absence of outliers for Westerpark and Noord-West suggests that the prices in these neighborhoods are more tightly clustered around the median, with fewer extreme high or low-priced listings. This could indicate a more uniform range of listing prices in these areas.
# 3) In conclusion we can see that there are luxury high-end listings in specific neighborhoods and there are also neighborhoods where it is moderately priced and more uniform listings are present.

# %% [markdown]
# ---

# %% [markdown]
# ### END OF ASSIGNMENT PYTHON SECTION

# %% [markdown]
# ---
